# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
from PIL import Image
import os
import pickle
import random
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from keras.models import Sequential, load_model
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    print("Name:", gpu.name, "  Type:", gpu.device_type)
# Out:
# Name: /physical_device:GPU:0   Type: GPU

# %%
tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From <ipython-input-4-17bb7203622b>:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %%
Dataset="/content/drive/MyDrive/Signature/BHSig260-Bengali/dataset"
Data_Dir=os.listdir(Dataset)
print(Data_Dir)
# Out:
# ['98', '95', '99', '97', '96', '94', '93', '92', '91', '90', '89', '87', '9', '86', '88', '85', '84', '83', '82', '81', '80', '78', '77', '79', '8', '76', '75', '74', '73', '72', '7', '68', '70', '69', '71', '67', '66', '65', '64', '63', '59', '61', '62', '6', '60', '58', '57', '56', '55', '54', '5', '50', '52', '53', '51', '49', '48', '47', '46', '45', '43', '42', '41', '44', '40', '4', '39', '38', '37', '36', '35', '34', '29', '28', '31', '30', '3', '33', '32', '27', '26', '25', '24', '23', '21', '22', '19', '20', '2', '18', '17', '16', '15', '14', '13', '1', '0', '12', '11', '10']

# %%
images = []
classNo = []
classes = 100
epochs_val = 50
batch_size = 32
imageDimensions = (360,100,3)

# %%
# Load the saved arrays
X_train = np.load('/content/drive/MyDrive/Signature/BHSig260-Bengali/Data_3_dim/X_train.npy')
X_test = np.load('/content/drive/MyDrive/Signature/BHSig260-Bengali/Data_3_dim/X_test.npy')
y_train = np.load('/content/drive/MyDrive/Signature/BHSig260-Bengali/Data_3_dim/y_train.npy')
y_test = np.load('/content/drive/MyDrive/Signature/BHSig260-Bengali/Data_3_dim/y_test.npy')

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (4320, 360, 100, 3) (1080, 360, 100, 3) (4320, 100) (1080, 100)

# %%
from keras.models import Model
from keras.applications.inception_v3 import InceptionV3
from keras.applications.inception_v3 import preprocess_input

# %%
Inc_V3 = InceptionV3(input_shape=imageDimensions, 
                  weights='imagenet', 
                  include_top=False)

for layer in Inc_V3.layers:
  layer.trainable = False

# %%
# No of layers
x = Flatten()(Inc_V3.output)
prediction = Dense(classes, activation='softmax')(x)

# create a model object
model = Model(inputs=Inc_V3.input, outputs=prediction)

# Compile the model
model.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

# %%
print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 360, 100, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 179, 49, 32)  864         ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 179, 49, 32)  96         ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 179, 49, 32)  0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 177, 47, 32)  9216        ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 177, 47, 32)  96         ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 177, 47, 32)  0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 177, 47, 64)  18432       ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 177, 47, 64)  192        ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 177, 47, 64)  0           ['batch_normalization_2[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 88, 23, 64)   0           ['activation_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 88, 23, 80)   5120        ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 88, 23, 80)  240         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 88, 23, 80)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 86, 21, 192)  138240      ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 86, 21, 192)  576        ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 86, 21, 192)  0           ['batch_normalization_4[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 42, 10, 192)  0          ['activation_4[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 42, 10, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 42, 10, 64)  192         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 42, 10, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 42, 10, 48)   9216        ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 42, 10, 96)   55296       ['activation_8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 42, 10, 48)  144         ['conv2d_6[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 42, 10, 96)  288         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 42, 10, 48)   0           ['batch_normalization_6[0][0]']
#
#  activation_9 (Activation)      (None, 42, 10, 96)   0           ['batch_normalization_9[0][0]']
#
#  average_pooling2d (AveragePool  (None, 42, 10, 192)  0          ['max_pooling2d_1[0][0]']
#  ing2D)
#
#  conv2d_5 (Conv2D)              (None, 42, 10, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 42, 10, 64)   76800       ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 42, 10, 96)   82944       ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 42, 10, 32)   6144        ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 42, 10, 64)  192         ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 42, 10, 64)  192         ['conv2d_7[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 42, 10, 96)  288         ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 42, 10, 32)  96          ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 42, 10, 64)   0           ['batch_normalization_5[0][0]']
#
#  activation_7 (Activation)      (None, 42, 10, 64)   0           ['batch_normalization_7[0][0]']
#
#  activation_10 (Activation)     (None, 42, 10, 96)   0           ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 42, 10, 32)   0           ['batch_normalization_11[0][0]']
#
#  mixed0 (Concatenate)           (None, 42, 10, 256)  0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 42, 10, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 42, 10, 64)  192         ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 42, 10, 64)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 42, 10, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 42, 10, 96)   55296       ['activation_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 42, 10, 48)  144         ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 42, 10, 96)  288         ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 42, 10, 48)   0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 42, 10, 96)   0           ['batch_normalization_16[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 42, 10, 256)  0          ['mixed0[0][0]']
#  oling2D)
#
#  conv2d_12 (Conv2D)             (None, 42, 10, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 42, 10, 64)   76800       ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 42, 10, 96)   82944       ['activation_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 42, 10, 64)   16384       ['average_pooling2d_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 42, 10, 64)  192         ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 42, 10, 64)  192         ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 42, 10, 96)  288         ['conv2d_17[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 42, 10, 64)  192         ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 42, 10, 64)   0           ['batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 42, 10, 64)   0           ['batch_normalization_14[0][0]']
#
#  activation_17 (Activation)     (None, 42, 10, 96)   0           ['batch_normalization_17[0][0]']
#
#  activation_18 (Activation)     (None, 42, 10, 64)   0           ['batch_normalization_18[0][0]']
#
#  mixed1 (Concatenate)           (None, 42, 10, 288)  0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]',
#                                                                   'activation_18[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 42, 10, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 42, 10, 64)  192         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 42, 10, 64)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 42, 10, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 42, 10, 96)   55296       ['activation_22[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 42, 10, 48)  144         ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 42, 10, 96)  288         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 42, 10, 48)   0           ['batch_normalization_20[0][0]']
#
#  activation_23 (Activation)     (None, 42, 10, 96)   0           ['batch_normalization_23[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 42, 10, 288)  0          ['mixed1[0][0]']
#  oling2D)
#
#  conv2d_19 (Conv2D)             (None, 42, 10, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 42, 10, 64)   76800       ['activation_20[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 42, 10, 96)   82944       ['activation_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 42, 10, 64)   18432       ['average_pooling2d_2[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 42, 10, 64)  192         ['conv2d_19[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 42, 10, 64)  192         ['conv2d_21[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 42, 10, 96)  288         ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 42, 10, 64)  192         ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 42, 10, 64)   0           ['batch_normalization_19[0][0]']
#
#  activation_21 (Activation)     (None, 42, 10, 64)   0           ['batch_normalization_21[0][0]']
#
#  activation_24 (Activation)     (None, 42, 10, 96)   0           ['batch_normalization_24[0][0]']
#
#  activation_25 (Activation)     (None, 42, 10, 64)   0           ['batch_normalization_25[0][0]']
#
#  mixed2 (Concatenate)           (None, 42, 10, 288)  0           ['activation_19[0][0]',
#                                                                   'activation_21[0][0]',
#                                                                   'activation_24[0][0]',
#                                                                   'activation_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 42, 10, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 42, 10, 64)  192         ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 42, 10, 64)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 42, 10, 96)   55296       ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 42, 10, 96)  288         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 42, 10, 96)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 20, 4, 384)   995328      ['mixed2[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 20, 4, 96)    82944       ['activation_28[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 20, 4, 384)  1152        ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 20, 4, 96)   288         ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 20, 4, 384)   0           ['batch_normalization_26[0][0]']
#
#  activation_29 (Activation)     (None, 20, 4, 96)    0           ['batch_normalization_29[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 20, 4, 288)  0           ['mixed2[0][0]']
#
#  mixed3 (Concatenate)           (None, 20, 4, 768)   0           ['activation_26[0][0]',
#                                                                   'activation_29[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 20, 4, 128)   98304       ['mixed3[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 20, 4, 128)  384         ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 20, 4, 128)   0           ['batch_normalization_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 20, 4, 128)   114688      ['activation_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 20, 4, 128)  384         ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 20, 4, 128)   0           ['batch_normalization_35[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 20, 4, 128)   98304       ['mixed3[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 20, 4, 128)   114688      ['activation_35[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 20, 4, 128)  384         ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_36 (BatchN  (None, 20, 4, 128)  384         ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 20, 4, 128)   0           ['batch_normalization_31[0][0]']
#
#  activation_36 (Activation)     (None, 20, 4, 128)   0           ['batch_normalization_36[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 20, 4, 128)   114688      ['activation_31[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 20, 4, 128)   114688      ['activation_36[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 20, 4, 128)  384         ['conv2d_32[0][0]']
#  ormalization)
#
#  batch_normalization_37 (BatchN  (None, 20, 4, 128)  384         ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 20, 4, 128)   0           ['batch_normalization_32[0][0]']
#
#  activation_37 (Activation)     (None, 20, 4, 128)   0           ['batch_normalization_37[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 20, 4, 768)  0           ['mixed3[0][0]']
#  oling2D)
#
#  conv2d_30 (Conv2D)             (None, 20, 4, 192)   147456      ['mixed3[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 20, 4, 192)   172032      ['activation_32[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 20, 4, 192)   172032      ['activation_37[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 20, 4, 192)   147456      ['average_pooling2d_3[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 20, 4, 192)  576         ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_33 (BatchN  (None, 20, 4, 192)  576         ['conv2d_33[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 20, 4, 192)  576         ['conv2d_38[0][0]']
#  ormalization)
#
#  batch_normalization_39 (BatchN  (None, 20, 4, 192)  576         ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 20, 4, 192)   0           ['batch_normalization_30[0][0]']
#
#  activation_33 (Activation)     (None, 20, 4, 192)   0           ['batch_normalization_33[0][0]']
#
#  activation_38 (Activation)     (None, 20, 4, 192)   0           ['batch_normalization_38[0][0]']
#
#  activation_39 (Activation)     (None, 20, 4, 192)   0           ['batch_normalization_39[0][0]']
#
#  mixed4 (Concatenate)           (None, 20, 4, 768)   0           ['activation_30[0][0]',
#                                                                   'activation_33[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_39[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 20, 4, 160)   122880      ['mixed4[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 20, 4, 160)  480         ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 20, 4, 160)   0           ['batch_normalization_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 20, 4, 160)   179200      ['activation_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 20, 4, 160)  480         ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 20, 4, 160)   0           ['batch_normalization_45[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 20, 4, 160)   122880      ['mixed4[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 20, 4, 160)   179200      ['activation_45[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 20, 4, 160)  480         ['conv2d_41[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 20, 4, 160)  480         ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 20, 4, 160)   0           ['batch_normalization_41[0][0]']
#
#  activation_46 (Activation)     (None, 20, 4, 160)   0           ['batch_normalization_46[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 20, 4, 160)   179200      ['activation_41[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 20, 4, 160)   179200      ['activation_46[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 20, 4, 160)  480         ['conv2d_42[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 20, 4, 160)  480         ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 20, 4, 160)   0           ['batch_normalization_42[0][0]']
#
#  activation_47 (Activation)     (None, 20, 4, 160)   0           ['batch_normalization_47[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 20, 4, 768)  0           ['mixed4[0][0]']
#  oling2D)
#
#  conv2d_40 (Conv2D)             (None, 20, 4, 192)   147456      ['mixed4[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 20, 4, 192)   215040      ['activation_42[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 20, 4, 192)   215040      ['activation_47[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 20, 4, 192)   147456      ['average_pooling2d_4[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 20, 4, 192)  576         ['conv2d_40[0][0]']
#  ormalization)
#
#  batch_normalization_43 (BatchN  (None, 20, 4, 192)  576         ['conv2d_43[0][0]']
#  ormalization)
#
#  batch_normalization_48 (BatchN  (None, 20, 4, 192)  576         ['conv2d_48[0][0]']
#  ormalization)
#
#  batch_normalization_49 (BatchN  (None, 20, 4, 192)  576         ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 20, 4, 192)   0           ['batch_normalization_40[0][0]']
#
#  activation_43 (Activation)     (None, 20, 4, 192)   0           ['batch_normalization_43[0][0]']
#
#  activation_48 (Activation)     (None, 20, 4, 192)   0           ['batch_normalization_48[0][0]']
#
#  activation_49 (Activation)     (None, 20, 4, 192)   0           ['batch_normalization_49[0][0]']
#
#  mixed5 (Concatenate)           (None, 20, 4, 768)   0           ['activation_40[0][0]',
#                                                                   'activation_43[0][0]',
#                                                                   'activation_48[0][0]',
#                                                                   'activation_49[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 20, 4, 160)   122880      ['mixed5[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 20, 4, 160)  480         ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 20, 4, 160)   0           ['batch_normalization_54[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 20, 4, 160)   179200      ['activation_54[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 20, 4, 160)  480         ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 20, 4, 160)   0           ['batch_normalization_55[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 20, 4, 160)   122880      ['mixed5[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 20, 4, 160)   179200      ['activation_55[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 20, 4, 160)  480         ['conv2d_51[0][0]']
#  ormalization)
#
#  batch_normalization_56 (BatchN  (None, 20, 4, 160)  480         ['conv2d_56[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 20, 4, 160)   0           ['batch_normalization_51[0][0]']
#
#  activation_56 (Activation)     (None, 20, 4, 160)   0           ['batch_normalization_56[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 20, 4, 160)   179200      ['activation_51[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 20, 4, 160)   179200      ['activation_56[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 20, 4, 160)  480         ['conv2d_52[0][0]']
#  ormalization)
#
#  batch_normalization_57 (BatchN  (None, 20, 4, 160)  480         ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 20, 4, 160)   0           ['batch_normalization_52[0][0]']
#
#  activation_57 (Activation)     (None, 20, 4, 160)   0           ['batch_normalization_57[0][0]']
#
#  average_pooling2d_5 (AveragePo  (None, 20, 4, 768)  0           ['mixed5[0][0]']
#  oling2D)
#
#  conv2d_50 (Conv2D)             (None, 20, 4, 192)   147456      ['mixed5[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 20, 4, 192)   215040      ['activation_52[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 20, 4, 192)   215040      ['activation_57[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 20, 4, 192)   147456      ['average_pooling2d_5[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 20, 4, 192)  576         ['conv2d_50[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 20, 4, 192)  576         ['conv2d_53[0][0]']
#  ormalization)
#
#  batch_normalization_58 (BatchN  (None, 20, 4, 192)  576         ['conv2d_58[0][0]']
#  ormalization)
#
#  batch_normalization_59 (BatchN  (None, 20, 4, 192)  576         ['conv2d_59[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 20, 4, 192)   0           ['batch_normalization_50[0][0]']
#
#  activation_53 (Activation)     (None, 20, 4, 192)   0           ['batch_normalization_53[0][0]']
#
#  activation_58 (Activation)     (None, 20, 4, 192)   0           ['batch_normalization_58[0][0]']
#
#  activation_59 (Activation)     (None, 20, 4, 192)   0           ['batch_normalization_59[0][0]']
#
#  mixed6 (Concatenate)           (None, 20, 4, 768)   0           ['activation_50[0][0]',
#                                                                   'activation_53[0][0]',
#                                                                   'activation_58[0][0]',
#                                                                   'activation_59[0][0]']
#
# ...
#  conv2d_80 (Conv2D)             (None, 9, 1, 448)    573440      ['mixed8[0][0]']
#
#  batch_normalization_80 (BatchN  (None, 9, 1, 448)   1344        ['conv2d_80[0][0]']
#  ormalization)
#
#  activation_80 (Activation)     (None, 9, 1, 448)    0           ['batch_normalization_80[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 9, 1, 384)    491520      ['mixed8[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 9, 1, 384)    1548288     ['activation_80[0][0]']
#
#  batch_normalization_77 (BatchN  (None, 9, 1, 384)   1152        ['conv2d_77[0][0]']
#  ormalization)
#
#  batch_normalization_81 (BatchN  (None, 9, 1, 384)   1152        ['conv2d_81[0][0]']
#  ormalization)
#
#  activation_77 (Activation)     (None, 9, 1, 384)    0           ['batch_normalization_77[0][0]']
#
#  activation_81 (Activation)     (None, 9, 1, 384)    0           ['batch_normalization_81[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 9, 1, 384)    442368      ['activation_77[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 9, 1, 384)    442368      ['activation_77[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 9, 1, 384)    442368      ['activation_81[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 9, 1, 384)    442368      ['activation_81[0][0]']
#
#  average_pooling2d_7 (AveragePo  (None, 9, 1, 1280)  0           ['mixed8[0][0]']
#  oling2D)
#
#  conv2d_76 (Conv2D)             (None, 9, 1, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_78 (BatchN  (None, 9, 1, 384)   1152        ['conv2d_78[0][0]']
#  ormalization)
#
#  batch_normalization_79 (BatchN  (None, 9, 1, 384)   1152        ['conv2d_79[0][0]']
#  ormalization)
#
#  batch_normalization_82 (BatchN  (None, 9, 1, 384)   1152        ['conv2d_82[0][0]']
#  ormalization)
#
#  batch_normalization_83 (BatchN  (None, 9, 1, 384)   1152        ['conv2d_83[0][0]']
#  ormalization)
#
#  conv2d_84 (Conv2D)             (None, 9, 1, 192)    245760      ['average_pooling2d_7[0][0]']
#
#  batch_normalization_76 (BatchN  (None, 9, 1, 320)   960         ['conv2d_76[0][0]']
#  ormalization)
#
#  activation_78 (Activation)     (None, 9, 1, 384)    0           ['batch_normalization_78[0][0]']
#
#  activation_79 (Activation)     (None, 9, 1, 384)    0           ['batch_normalization_79[0][0]']
#
#  activation_82 (Activation)     (None, 9, 1, 384)    0           ['batch_normalization_82[0][0]']
#
#  activation_83 (Activation)     (None, 9, 1, 384)    0           ['batch_normalization_83[0][0]']
#
#  batch_normalization_84 (BatchN  (None, 9, 1, 192)   576         ['conv2d_84[0][0]']
#  ormalization)
#
#  activation_76 (Activation)     (None, 9, 1, 320)    0           ['batch_normalization_76[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 9, 1, 768)    0           ['activation_78[0][0]',
#                                                                   'activation_79[0][0]']
#
#  concatenate (Concatenate)      (None, 9, 1, 768)    0           ['activation_82[0][0]',
#                                                                   'activation_83[0][0]']
#
#  activation_84 (Activation)     (None, 9, 1, 192)    0           ['batch_normalization_84[0][0]']
#
#  mixed9 (Concatenate)           (None, 9, 1, 2048)   0           ['activation_76[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate[0][0]',
#                                                                   'activation_84[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 9, 1, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_89 (BatchN  (None, 9, 1, 448)   1344        ['conv2d_89[0][0]']
#  ormalization)
#
#  activation_89 (Activation)     (None, 9, 1, 448)    0           ['batch_normalization_89[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 9, 1, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 9, 1, 384)    1548288     ['activation_89[0][0]']
#
#  batch_normalization_86 (BatchN  (None, 9, 1, 384)   1152        ['conv2d_86[0][0]']
#  ormalization)
#
#  batch_normalization_90 (BatchN  (None, 9, 1, 384)   1152        ['conv2d_90[0][0]']
#  ormalization)
#
#  activation_86 (Activation)     (None, 9, 1, 384)    0           ['batch_normalization_86[0][0]']
#
#  activation_90 (Activation)     (None, 9, 1, 384)    0           ['batch_normalization_90[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 9, 1, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 9, 1, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 9, 1, 384)    442368      ['activation_90[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 9, 1, 384)    442368      ['activation_90[0][0]']
#
#  average_pooling2d_8 (AveragePo  (None, 9, 1, 2048)  0           ['mixed9[0][0]']
#  oling2D)
#
#  conv2d_85 (Conv2D)             (None, 9, 1, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_87 (BatchN  (None, 9, 1, 384)   1152        ['conv2d_87[0][0]']
#  ormalization)
#
#  batch_normalization_88 (BatchN  (None, 9, 1, 384)   1152        ['conv2d_88[0][0]']
#  ormalization)
#
#  batch_normalization_91 (BatchN  (None, 9, 1, 384)   1152        ['conv2d_91[0][0]']
#  ormalization)
#
#  batch_normalization_92 (BatchN  (None, 9, 1, 384)   1152        ['conv2d_92[0][0]']
#  ormalization)
#
#  conv2d_93 (Conv2D)             (None, 9, 1, 192)    393216      ['average_pooling2d_8[0][0]']
#
#  batch_normalization_85 (BatchN  (None, 9, 1, 320)   960         ['conv2d_85[0][0]']
#  ormalization)
#
#  activation_87 (Activation)     (None, 9, 1, 384)    0           ['batch_normalization_87[0][0]']
#
#  activation_88 (Activation)     (None, 9, 1, 384)    0           ['batch_normalization_88[0][0]']
#
#  activation_91 (Activation)     (None, 9, 1, 384)    0           ['batch_normalization_91[0][0]']
#
#  activation_92 (Activation)     (None, 9, 1, 384)    0           ['batch_normalization_92[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 9, 1, 192)   576         ['conv2d_93[0][0]']
#  ormalization)
#
#  activation_85 (Activation)     (None, 9, 1, 320)    0           ['batch_normalization_85[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 9, 1, 768)    0           ['activation_87[0][0]',
#                                                                   'activation_88[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 9, 1, 768)    0           ['activation_91[0][0]',
#                                                                   'activation_92[0][0]']
#
#  activation_93 (Activation)     (None, 9, 1, 192)    0           ['batch_normalization_93[0][0]']
#
#  mixed10 (Concatenate)          (None, 9, 1, 2048)   0           ['activation_85[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_1[0][0]',
#                                                                   'activation_93[0][0]']
#
#  flatten (Flatten)              (None, 18432)        0           ['mixed10[0][0]']
#
#  dense (Dense)                  (None, 100)          1843300     ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 23,646,084
# Trainable params: 1,843,300
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________
# None

# %%
history = model.fit(X_train, 
                    y_train, 
                    batch_size=batch_size, 
                    epochs=epochs_val, 
                    validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 135/135 [==============================] - 33s 95ms/step - loss: 879.9739 - accuracy: 0.1282 - val_loss: 261.2300 - val_accuracy: 0.2306
# Epoch 2/50
# 135/135 [==============================] - 7s 51ms/step - loss: 172.1627 - accuracy: 0.3815 - val_loss: 156.4093 - val_accuracy: 0.4056
# Epoch 3/50
# 135/135 [==============================] - 7s 53ms/step - loss: 139.3098 - accuracy: 0.4954 - val_loss: 126.6040 - val_accuracy: 0.5000
# Epoch 4/50
# 135/135 [==============================] - 7s 51ms/step - loss: 114.3461 - accuracy: 0.5620 - val_loss: 135.2342 - val_accuracy: 0.4991
# Epoch 5/50
# 135/135 [==============================] - 8s 61ms/step - loss: 119.9619 - accuracy: 0.5738 - val_loss: 132.1866 - val_accuracy: 0.5583
# Epoch 44/50
# 135/135 [==============================] - 8s 62ms/step - loss: 33.9493 - accuracy: 0.9125 - val_loss: 131.8882 - val_accuracy: 0.7769
# Epoch 45/50
# 135/135 [==============================] - 8s 61ms/step - loss: 38.2415 - accuracy: 0.9132 - val_loss: 132.8842 - val_accuracy: 0.7907
# Epoch 46/50
# 135/135 [==============================] - 7s 54ms/step - loss: 25.3476 - accuracy: 0.9319 - val_loss: 106.6406 - val_accuracy: 0.8065
# Epoch 47/50
# 135/135 [==============================] - 7s 52ms/step - loss: 34.2291 - accuracy: 0.9204 - val_loss: 137.0316 - val_accuracy: 0.7759
# Epoch 48/50
# 135/135 [==============================] - 7s 54ms/step - loss: 30.9635 - accuracy: 0.9218 - val_loss: 141.8438 - val_accuracy: 0.7639
# Epoch 49/50
# 135/135 [==============================] - 7s 53ms/step - loss: 42.0051 - accuracy: 0.9090 - val_loss: 131.0605 - val_accuracy: 0.8204
# Epoch 50/50
# 135/135 [==============================] - 7s 54ms/step - loss: 26.4571 - accuracy: 0.9301 - val_loss: 149.4669 - val_accuracy: 0.7843

# %%
plt.figure(0)
plt.plot(history.history['accuracy'], label='training accuracy')
plt.plot(history.history['val_accuracy'], label='val accuracy')
plt.title('Accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

plt.figure(1)
plt.plot(history.history['loss'], label='training loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.title('Loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
score = model.evaluate(X_train, y_train, verbose=0)
print('Train accuracy:', score[1])
# Out:
# Train accuracy: 0.9298611283302307

# %%
score = model.evaluate(X_test, y_test, verbose=0)
print('Test accuracy:', score[1])
# Out:
# Test accuracy: 0.7842592597007751

# %%
pred = np.argmax(model.predict(X_test), axis = 1)
# Out:
# 34/34 [==============================] - 3s 41ms/step

# %%
actual=np.argmax(y_test, axis = 1)

# %%
cm = confusion_matrix(actual, pred)
# cm_df = pd.DataFrame(cm)

plt.figure(figsize = (8,8))
sns.heatmap(cm, annot = True,cmap='BuPu',cbar=False,linewidth=2,fmt='d')
plt.title('Signature')
plt.ylabel('True class')
plt.xlabel('Prediction class')
plt.show()

# %%
cf = classification_report(actual, pred)
print(cf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.93        14
#            1       1.00      1.00      1.00         5
#            2       0.87      0.87      0.87        15
#            3       1.00      1.00      1.00         7
#            4       1.00      0.92      0.96        12
#            5       0.91      1.00      0.95        10
#            6       1.00      0.50      0.67         6
#            7       1.00      0.93      0.96        14
#            8       1.00      0.69      0.82        13
#            9       1.00      1.00      1.00        20
#           10       0.89      1.00      0.94        16
#           11       0.82      0.90      0.86        10
#           12       0.00      0.00      0.00        10
#           13       0.53      1.00      0.69        10
#           14       0.32      1.00      0.48         6
#           15       1.00      0.08      0.15        12
#           16       1.00      0.21      0.35        14
#           17       0.86      0.75      0.80         8
#           18       1.00      0.50      0.67        14
#           19       0.86      1.00      0.92         6
